# %% [markdown]
# ## Apply your skills
# # Instructions
#
# So far, you have worked with the Minnesota birds dataset to discover information about bird quantities and population density. Practice your application of these techniques by trying a different dataset, perhaps sourced from Kaggle. Build a notebook to tell a story about this dataset, and make sure to use histograms when discussing it.
#
# ## Rubric
# Exemplary	Adequate	Needs Improvement
# A notebook is presented with annotations about this dataset, including its source, and uses at least 5 histograms to discover facts about the data.	A notebook is presented with incomplete annotations or bugs.	A notebook is presented without annotations and includes bugs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
path = r"C:\Users\LENOVO\Cohort-3.0-Machine-Learning-Assignments\data\penguins_lter.csv"

# Show first few rows
df = pd.read_csv(path)
print(df.head())
print(df.info())
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Drop missing values for simplicity
df.dropna(inplace=True)

# Basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 6 to 139
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            13 non-null     object
#  1   Sample Number        13 non-null     int64
#  2   Species              13 non-null     object
#  3   Region               13 non-null     object
#  4   Island               13 non-null     object
#  5   Stage                13 non-null     object
#  6   Individual ID        13 non-null     object
#  7   Clutch Completion    13 non-null     object
#  8   Date Egg             13 non-null     object
#  9   Culmen Length (mm)   13 non-null     float64
#  10  Culmen Depth (mm)    13 non-null     float64
#  11  Flipper Length (mm)  13 non-null     float64
#  12  Body Mass (g)        13 non-null     float64
#  13  Sex                  13 non-null     object
#  14  Delta 15 N (o/oo)    13 non-null     float64
# ...

# %% [markdown]
# 📊 Histogram 1: Flipper Length Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Flipper Length (mm)'], bins=20, kde=True)
plt.title('Distribution of Flipper Length')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 📊 Histogram 2: Body Mass by Species

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x='Body Mass (g)', hue='Species', bins=20, kde=True)
plt.title('Body Mass Distribution by Species')
plt.xlabel('Body Mass (g)')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 📊 Histogram 3: Culmen Depth

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Culmen Depth (mm)'], bins=15, color='orange')
plt.title('Distribution of Culmen Depth')
plt.xlabel('Culmen Depth (mm)')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 📊 Histogram 4: Flipper Length by Sex

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x='Flipper Length (mm)', hue='Sex', bins=20, kde=True)
plt.title('Flipper Length Distribution by Sex')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 📊 Histogram 5: Island Distribution

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='Island', hue='Species', multiple='stack')
plt.title('Penguin Species Count by Island')
plt.xlabel('Island')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Summary

# %% [markdown]
# - Penguins show distinct biometric differences across species and sexes.
# - Histograms helped reveal patterns in flipper length, mass, and species distribution.
# - This dataset provides a more approachable and ethical alternative to seabird studies from less accessible regions.
